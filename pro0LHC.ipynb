# %% [markdown]
# # StatMech Assignment 1
# ## Name: Hsiao-Chin Liu               ID: 106022555
# ## Problem 0: One die with 6 sides

# %% [markdown]
# 1.Write a program (or modify the one given) to calculate and print out the histogram of the number of times each side occurs, the deviation of this number from one-sixth of the number of trials, the frequency with which each side occurs, and the deviation of this from one sixth. Hand in a copy of the code you used.

# %% [markdown]
# import random
# import time
#
# def onedie(trials):
#     c1=time.clock()
#     print("====================")
#     print("One die with 6 sides")
#     print("Number of trials = ", trials)
#
#     sides = 6
#     histogram = [0, 0, 0, 0, 0, 0]
#     print(histogram)
#
#     j = 0
#     r = 0
#     while j < trials :
#         r = int(random.random()*sides) # Faster
#
#         histogram[r] = histogram[r] + 1
#         j = j + 1
#
#     print("s, N_s, N_s-N/6, N_s/N, N_s/N-1/6")
#     #s=side,N_s=the number of the side occurs, N=the number of trials
#
#     j = 0
#     while j < sides:
#         print(j+1, histogram[j], histogram[j]-trials/sides, histogram[j]/trials, histogram[j]/trials-1/6)
#         j = j + 1
#
#     c2=time.clock()
#     print("Elapsed time =", c2-c1)
#
# def run():
#     onedie(1)
#     onedie(20)
#     onedie(300)
#     onedie(4000)
#     onedie(50000)
#     onedie(600000)
#     onedie(900000)
#     onedie(1000000)
#     onedie(1100000)
#     onedie(1200000)
#     onedie(1300000)
# run()

# %%
2.Show a typical print-out of your program.

# %%
====================
One die with 6 sides
Number of trials =  1
[0, 0, 0, 0, 0, 0]
s, N_s, N_s-N/6, N_s/N, N_s/N-1/6
1 0 -0.16666666666666666 0.0 -0.16666666666666666
2 0 -0.16666666666666666 0.0 -0.16666666666666666
3 1 0.8333333333333334 1.0 0.8333333333333334
4 0 -0.16666666666666666 0.0 -0.16666666666666666
5 0 -0.16666666666666666 0.0 -0.16666666666666666
6 0 -0.16666666666666666 0.0 -0.16666666666666666
Elapsed time = 0.0009819025015076477
====================
One die with 6 sides
Number of trials =  20
[0, 0, 0, 0, 0, 0]
s, N_s, N_s-N/6, N_s/N, N_s/N-1/6
1 5 1.6666666666666665 0.25 0.08333333333333334
2 3 -0.3333333333333335 0.15 -0.016666666666666663
3 1 -2.3333333333333335 0.05 -0.11666666666666665
4 4 0.6666666666666665 0.2 0.033333333333333354
5 2 -1.3333333333333335 0.1 -0.06666666666666665
6 5 1.6666666666666665 0.25 0.08333333333333334
Elapsed time = 0.001448960412147926
====================
One die with 6 sides
Number of trials =  300
[0, 0, 0, 0, 0, 0]
s, N_s, N_s-N/6, N_s/N, N_s/N-1/6
1 59 9.0 0.19666666666666666 0.03
2 50 0.0 0.16666666666666666 0.0
3 47 -3.0 0.15666666666666668 -0.009999999999999981
4 52 2.0 0.17333333333333334 0.006666666666666682
5 42 -8.0 0.14 -0.026666666666666644
6 50 0.0 0.16666666666666666 0.0
1 183847 513.666666666657 0.16713363636363637 0.0004669696969697157
2 182112 -1221.333333333343 0.16555636363636364 -0.001110303030303017
3 183423 89.66666666665697 0.16674818181818182 8.151515151516575e-05
4 183739 405.66666666665697 0.16703545454545454 0.0003687878787878851
5 183266 -67.33333333334303 0.16660545454545456 -6.121212121210085e-05
6 183613 279.66666666665697 0.1669209090909091 0.0002542424242424346
Elapsed time = 0.8882030615333179
====================
One die with 6 sides
Number of trials =  1200000
[0, 0, 0, 0, 0, 0]
s, N_s, N_s-N/6, N_s/N, N_s/N-1/6
1 200148 148.0 0.16679 0.0001233333333333364
2 199979 -21.0 0.16664916666666665 -1.7500000000003624e-05
3 200157 157.0 0.1667975 0.00013083333333333003
4 200517 517.0 0.1670975 0.0004308333333333525
5 199866 -134.0 0.166555 -0.00011166666666664882
6 199333 -667.0 0.16611083333333335 -0.000555833333333311
Elapsed time = 0.9612216778586173
====================
One die with 6 sides
Number of trials =  1300000
[0, 0, 0, 0, 0, 0]
s, N_s, N_s-N/6, N_s/N, N_s/N-1/6
1 216756 89.33333333334303 0.16673538461538462 6.871794871796122e-05
2 215991 -675.666666666657 0.16614692307692308 -0.0005197435897435765
3 216966 299.33333333334303 0.16689692307692308 0.00023025641025642418
4 216546 -120.66666666665697 0.16657384615384616 -9.282051282050174e-05
5 217028 361.33333333334303 0.16694461538461539 0.00027794871794872833
6 216713 46.333333333343035 0.1667023076923077 3.564102564104776e-05
Elapsed time = 1.0406107137737024

# %% [markdown]
# 3.Run the program for various numbers of random integers, starting with a small number, say 10, and increasing to a substantially larger number. The only upper limit is that the program should not take more than about one second to run. ([Your time is valuable.) THIS IS A COMPUTATIONAL PROBLEM. ANSWERS MUST BE ACCOMPANIED BY DATA. Please hand in hard copies for all data to which you refer in your answers.

# %% [markdown]
# | s, | N_s,   | N_s-N/6, | N_s/N,              | N_s/N-1/6               |
# |----|--------|----------|---------------------|-------------------------|
# | 1  | 200148 | 148.0    | 0.16679             | 0.0001233333333333364   |
# | 2  | 199979 | -21.0    | 0.16664916666666665 | -1.7500000000003624e-05 |
# | 3  | 200157 | 157.0    | 0.1667975           | 0.00013083333333333003  |
# | 4  | 200517 | 517.0    | 0.1670975           | 0.0004308333333333525   |
# | 5  | 199866 | -134.0   | 0.166555            | -0.00011166666666664882 |
# | 6  | 199333 | -667.0   | 0.16611083333333335 | -0.000555833333333311   |
#
# Number of trials =  1200000

# %% [markdown]
# 4.As the number of trials increases, does the magnitude (absolute value) of the differences between the number of times a given side occurs and one-sixth of the number of trials increase or decrease? (Hint: This is not the same question as the next one.)

# %% [markdown]
#  N_s/N-1/6 will decrease.

# %% [markdown]
# 5.As you increase the number of trials, does the ratio of the number of times each side occurs to the total number of trials approach closer to 1/6?

# %%
yes.
